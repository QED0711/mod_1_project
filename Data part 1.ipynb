# %%
# !ls ./data/
# Out:
# bom.movie_gross.csv.gz	  imdb.title.crew.csv.gz	rt.reviews.tsv.gz
# imdb.name.basics.csv.gz   imdb.title.principals.csv.gz	tmdb.movies.csv.gz
# imdb.title.akas.csv.gz	  imdb.title.ratings.csv.gz	tn.movie_budgets.csv.gz
# imdb.title.basics.csv.gz  rt.movie_info.tsv.gz

# %%
pd.read_csv('./data/bom.movie_gross.csv.gz').head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
import pandas as pd
import numpy as np



# principals_df = pd.read_csv('./data/imdb.title.principals.csv.gz')
# basics_df = pd.read_csv('./data/imdb.name.basics.csv.gz')
# gross_df = pd.read_csv('./data/bom.movie_gross.csv.gz')
# akas_df = pd.read_csv('./data/imdb.title.akas.csv.gz')
# bom_df = pd.read_csv('./data/bom.movie_gross.csv.gz')
# tm_movies_db = pd.read_csv('./data/tmdb.movies.csv.gz')
# tm_movies2_db = pd.read_json('./data/tmdb.movie_ids.json.gz')

# %%
bom_df.head(20)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
b_and_p_df = basics_df.merge(principals_df, on="nconst")

# %% [markdown]
# # GENERAL QUESTIONS:
#
# - [ ] genre frequency?
# - [ ] rise in actors of color - should ms fund eg asian cast movies
# - [ ] ratio of budget to box office - key metrics
# - [ ] what are similarities of highest rated movies, highest grossing
# - [ ] should ms look into foreign films, markets
# - [ ] does a foreign actor/studio make that film better in that country
# - [ ] could ms use existing products to promote new viewing tech in the home environment (holo lense, kinect)
# - [ ] number of user ratings (populist) against gross
#     - [ ] how to cut through rating bias (rating vs rating count vs popularity)
# - [ ] what movies perform better online than in theaters
# - [ ] how to calculate VORM - what is the best way to rate success of a film
#     - [ ] how do you define as the reference point

# %% [markdown]
# # GRAPHS:
#
# 1. rating vs ROI (return on investment) - (create net revenue vs ratings)
# 2. ROI vs awards
# 3. rating and budget vs investment
# 4. ratings vs gross revenue
# 5. ratings vs budget

# %% [markdown]
# # GOALS:
#
# ### OVERALL:
#
# - should ms get into the movie streaming service
# - if so, what is the most profitable direction
# - How can they be unique in the landscape
