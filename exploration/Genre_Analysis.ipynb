# %% [markdown]
# # Summary
#
# This notebook contains the code necessary to recreate our analysis of the effects of genre and visual enhancements on the total gross income of a movie.
#
# #### 1. Imports
# #### 2. Data Read-In
# #### 3. Merges
# #### 4. Data Cleaning & Processing
# #### 5. Analysis & Graphs
# ***

# %% [markdown]
# ## 1. IMPORTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pdb

from cleaning_scripts import *

# %matplotlib inline
sns.set_style('darkgrid')

# %% [markdown]
# ## 2. DATA READ-IN

# %%
basics_df = pd.read_csv('./data/imdb.title.basics.csv.gz')
gross_df = pd.read_csv('./data/bom.movie_gross.csv.gz')
akas_df = pd.read_csv('./data/imdb.title.akas.csv.gz')

final_df = pd.read_csv('./data/final.csv')
final_df.drop(['gross_unscaled'], axis=1, inplace=True)
final_df.to_csv('./data/final.csv')

# %% [markdown]
# ## 3. MERGES (unnecessary now because of final.csv)

# %%
# # basics_df:
# # rename tconst => title_id
# basics_df.rename(columns={'tconst': 'title_id'}, inplace=True)

# # merge basics and akas dfs
# # store in new df => common_id_df
# common_id_df = basics_df.merge(akas_df, on='title_id', how='inner')

# # gross_df:
# # rename title => primary_title
# gross_df.rename(columns={'title': 'primary_title'}, inplace=True)

# # merge common_id and gross dfs
# # store in new df => final_df
# final_df = common_id_df.merge(gross_df, on='primary_title', how='inner')

# %% [markdown]
# ## 4. DATA CLEANING & PROCESSING

# %%
# make sure domestic & foreign gross are both float types
final_df.domestic_gross = pd.to_numeric(final_df.domestic_gross, errors='coerce')
final_df.foreign_gross = pd.to_numeric(final_df.foreign_gross, errors='coerce')

# replace any gross na values with 0.0 (assuming an na means not presented domestically/internationally)
final_df.domestic_gross.fillna(0.0, inplace=True)
final_df.foreign_gross.fillna(0.0, inplace=True)

# add total_gross column, express value in billions
final_df['total_gross'] = final_df.domestic_gross + final_df.foreign_gross
final_df.total_gross = final_df.total_gross / 1_000_000_000

# drop repated movie listings that result in the same total_gross (these are just repeat listings)
unique_titles = final_df.drop_duplicates(subset=['primary_title', 'total_gross'])

# %% [markdown]
# ### 4b. SUBSET DATAFRAMES

# %%
# performant_genres: An ordered listing of the top 10 genre labels with the highest total_gross 
performant_genres = unique_titles.groupby("genres").sum().sort_values('total_gross', ascending=False).iloc[0:10, -1:]

# top subgenres: a cimple count of occurances of subgenres within the top performant genres
#     process subgenres
subgenres = get_subgenres(performant_genres.reset_index().genres)
top_subgenres = subgenre_counter(subgenres, performant_genres.reset_index())
#     Create subgenres dataframe
top_subgenres_df = pd.DataFrame(top_subgenres.items())
top_subgenres_df.columns = ["Genre", "Count"]
top_subgenres_df = top_subgenres_df.sort_values('Count', ascending=False)

# visually_enhanced: subset of movies with visual enhancements (3d or IMAX), grouped by genres
visually_enhanced = final_df[final_df.attributes.isin(['3-D version', 'IMAX version'])].sort_values('total_gross', ascending=False).loc[:, ["primary_title","total_gross"]]
top_visually_enhanced = visually_enhanced.groupby('primary_title').sum().sort_values('total_gross', ascending=False).iloc[:10, -1:]

# special_attributes: final_df grouped by attributes and sorted by total gross
special_attributes = final_df.groupby('attributes').sum().sort_values('total_gross', ascending=False)[0:12]

# %% [markdown]
# ***
# # == CHECKPOINT ==
#
# final_df has all data needed for this analysis
# performant_genres, top_subgenres_df, visual_enhancements, & special_attributes subset for analysis
# ***

# %% [markdown]
# ## 5. ANALYSIS & GRAPHS

# %% [markdown]
# ### Question 1. Towards what genres should Microsoft direct its resources to maximize gross income

# %% [markdown]
# ***
# #### Top grossing genres

# %%
performant_genres
# Out:
#                             total_gross
# genres
# Action,Adventure,Sci-Fi       27.636100
# Adventure,Animation,Comedy    25.448726
# Action,Adventure,Fantasy      13.314887
# Action,Adventure,Comedy        9.563595
# Action,Adventure,Animation     6.454160
# Action,Adventure,Thriller      6.278398
# Action,Adventure,Drama         4.933278
# Comedy                         4.477626
# Action,Thriller                3.787685
# Action,Crime,Thriller          3.381129

# %%
plt.figure(figsize=(20, 5))
ax1 = plt.subplot(121, xlabel="Total Gross")
ax1.set_xlabel("Total Gross (billions)")
ax1.set_ylabel("Total")
ax1.set_title("Top Performant Genres by Total Gross")

ax2 = plt.subplot(122)
ax2.set_title("Subgenre Counts in Top 10 Genres")

sns.barplot(data=performant_genres, y=performant_genres.index, x='total_gross', orient='h', ax=ax1, color="#E67E17")
sns.barplot(data=top_subgenres_df, x="Count", y='Genre', ax=ax2, color="#366DA2")
plt.subplots_adjust(wspace=0.2)
plt.show()

# %%
sns.barplot(data=performant_genres, y=performant_genres.index, x='total_gross', orient='h')

plt.title("Top Performant Genres by Total Gross")
plt.xlabel("Total Gross (billions)")
plt.ylabel("Genres")

plt.show()

# %% [markdown]
# #### Analysis:
#
# The above chart shows how well each genre (long form) performed at the boxoffice. From this, we can see that the top two genres, (Action, Adventure, Sci-Fi) & (Adventure, Animation, Comedy) significantly outperformed the other genre categories.
#
# From a cursory glance, it would appear as if there is a high number of Adventure and Action films in this list. The anecdotal evidence suggests that MS may want to invest its time and efforts in Action/Adventure content to maximize profits.

# %% [markdown]
# ***
# #### Subgenres within performant genres

# %%
sns.barplot(data=top_subgenres_df, x="Count", y='Genre')
plt.xlabel("Appearances in Top 10")
plt.ylabel("Subgenre")
plt.title("Subgenre Counts from Top 10 Genres")
# Out:
# Text(0.5, 1.0, 'Subgenre Counts from Top 10 Genres')

# %% [markdown]
# #### Analysis:
#
# Further exploration of the subgenres in the top 10 performant genres reveals that our original assumption of the high yieled of action and adventure films was accurate. We can see more clearly with this chart that both action and adeventure subgenres appear more than double the amount of times in the genre listings of the top performant genres.
#
# Our recommendation holds that MS should direct its resources towards action and adventure movies.

# %% [markdown]
# ### Question 2 - Microsoft has become increasingly focused on hardware in the last two decades (xbox, hololens, etc.). How can they leverage their inbuilt technological advantages in their media streaming service?

# %%
sns.barplot(data=top_visually_enhanced, x='total_gross', y=top_visually_enhanced.index)
plt.ylabel("Movie")
plt.xlabel("Total Gross (billions)")
plt.title("Top 10 Grossing Movies with Enhanced Visual Element")
# Out:
# Text(0.5, 1.0, 'Top 10 Grossing Movies with Enhanced Visual Element')

# %% [markdown]
# #### Analysis:
#
# We believe it is wise for Microsoft to use its existing line of media hardware to help carve a distinguishable path in this crowded product landscape.
#
# The chart above shows to gross income in billions of the top 10 highest grossing movies that had some visual enhancement (3D or IMAX versions). It is our suggestion that Microsoft use these films as models for further study to create similar productions that could also take advantage of their media technology.

# %%
final_df
# Out:
#        Unnamed: 0   title_id              primary_title  \
# 0               0  tt0315642                      Wazir
# 1               1  tt0315642                      Wazir
# 2               2  tt0315642                      Wazir
# 3               3  tt0315642                      Wazir
# 4               4  tt0315642                      Wazir
# 5               5  tt0315642                      Wazir
# 6               6  tt0337692                On the Road
# 7               7  tt0337692                On the Road
# 8               8  tt0337692                On the Road
# 9               9  tt0337692                On the Road
# 10             10  tt0337692                On the Road
# 11             11  tt0337692                On the Road
# 12             12  tt0337692                On the Road
# 13             13  tt0337692                On the Road
# 14             14  tt0337692                On the Road
# 15             15  tt0337692                On the Road
# 16             16  tt0337692                On the Road
# 17             17  tt0337692                On the Road
# 18             18  tt0337692                On the Road
# 19             19  tt0337692                On the Road
# 20             20  tt0337692                On the Road
# 21             21  tt0337692                On the Road
# 22             22  tt0337692                On the Road
# 23             23  tt0337692                On the Road
# 24             24  tt0337692                On the Road
# 25             25  tt0337692                On the Road
# 26             26  tt0337692                On the Road
# 27             27  tt0337692                On the Road
# 28             28  tt0337692                On the Road
# 29             29  tt0337692                On the Road
# ...           ...        ...                        ...
# 54704       54704  tt8290698         The Spy Gone North
# 54705       54705  tt8290698         The Spy Gone North
# 54706       54706  tt8290698         The Spy Gone North
# 54707       54707  tt8290698         The Spy Gone North
# 54708       54708  tt8290698         The Spy Gone North
# 54709       54709  tt8290698         The Spy Gone North
# 54710       54710  tt8290698         The Spy Gone North
# 54711       54711  tt8331988            The Chambermaid
# 54712       54712  tt8331988            The Chambermaid
# 54713       54713  tt8331988            The Chambermaid
# 54714       54714  tt8331988            The Chambermaid
# 54715       54715  tt8331988            The Chambermaid
# 54716       54716  tt8331988            The Chambermaid
# 54717       54717  tt8404272     How Long Will I Love U
# 54718       54718  tt8404272     How Long Will I Love U
# 54719       54719  tt8404272     How Long Will I Love U
# 54720       54720  tt8404272     How Long Will I Love U
# 54721       54721  tt8427036            Helicopter Eela
# 54722       54722  tt8427036            Helicopter Eela
# 54723       54723  tt8427036            Helicopter Eela
# 54724       54724  tt9078374                Last Letter
# 54725       54725  tt9078374                Last Letter
# 54726       54726  tt9078374                Last Letter
# 54727       54727  tt9151704  Burn the Stage: The Movie
# 54728       54728  tt9151704  Burn the Stage: The Movie
# 54729       54729  tt9151704  Burn the Stage: The Movie
# 54730       54730  tt9151704  Burn the Stage: The Movie
# 54731       54731  tt9151704  Burn the Stage: The Movie
# 54732       54732  tt9151704  Burn the Stage: The Movie
# 54733       54733  tt9151704  Burn the Stage: The Movie
#
#                   original_title  start_year  runtime_minutes  \
# 0                          Wazir        2016            103.0
# 1                          Wazir        2016            103.0
# 2                          Wazir        2016            103.0
# 3                          Wazir        2016            103.0
# 4                          Wazir        2016            103.0
# 5                          Wazir        2016            103.0
# 6                    On the Road        2012            124.0
# 7                    On the Road        2012            124.0
# 8                    On the Road        2012            124.0
# 9                    On the Road        2012            124.0
# 10                   On the Road        2012            124.0
# 11                   On the Road        2012            124.0
# 12                   On the Road        2012            124.0
# 13                   On the Road        2012            124.0
# 14                   On the Road        2012            124.0
# 15                   On the Road        2012            124.0
# 16                   On the Road        2012            124.0
# 17                   On the Road        2012            124.0
# 18                   On the Road        2012            124.0
# 19                   On the Road        2012            124.0
# 20                   On the Road        2012            124.0
# 21                   On the Road        2012            124.0
# 22                   On the Road        2012            124.0
# 23                   On the Road        2012            124.0
# 24                   On the Road        2012            124.0
# 25                   On the Road        2012            124.0
# 26                   On the Road        2012            124.0
# 27                   On the Road        2012            124.0
# 28                   On the Road        2012            124.0
# 29                   On the Road        2012            124.0
# ...                          ...         ...              ...
# 54704                    Gongjak        2018            137.0
# 54705                    Gongjak        2018            137.0
# 54706                    Gongjak        2018            137.0
# 54707                    Gongjak        2018            137.0
# 54708                    Gongjak        2018            137.0
# 54709                    Gongjak        2018            137.0
# 54710                    Gongjak        2018            137.0
# 54711               La camarista        2018            102.0
# 54712               La camarista        2018            102.0
# 54713               La camarista        2018            102.0
# 54714               La camarista        2018            102.0
# 54715               La camarista        2018            102.0
# 54716               La camarista        2018            102.0
# 54717      Chao shi kong tong ju        2018            101.0
# 54718      Chao shi kong tong ju        2018            101.0
# 54719      Chao shi kong tong ju        2018            101.0
# 54720      Chao shi kong tong ju        2018            101.0
# 54721            Helicopter Eela        2018            135.0
# 54722            Helicopter Eela        2018            135.0
# 54723            Helicopter Eela        2018            135.0
# 54724             Ni hao, Zhihua        2018            114.0
# 54725             Ni hao, Zhihua        2018            114.0
# 54726             Ni hao, Zhihua        2018            114.0
# 54727  Burn the Stage: The Movie        2018             84.0
# 54728  Burn the Stage: The Movie        2018             84.0
# 54729  Burn the Stage: The Movie        2018             84.0
# 54730  Burn the Stage: The Movie        2018             84.0
# 54731  Burn the Stage: The Movie        2018             84.0
# 54732  Burn the Stage: The Movie        2018             84.0
# 54733  Burn the Stage: The Movie        2018             84.0
#
#                         genres  ordering                        title region  \
# 0           Action,Crime,Drama         1                        Wazir    NaN
# 1           Action,Crime,Drama         2                   64 Squares    NaN
# 2           Action,Crime,Drama         3                        Wazir     IN
# 3           Action,Crime,Drama         4                       Move 5     IN
# 4           Action,Crime,Drama         5              The Last Square     IN
# 5           Action,Crime,Drama         6                        Ферзь     RU
# 6      Adventure,Drama,Romance        10                 En el camino     AR
# 7      Adventure,Drama,Romance        11      On the Road - Unterwegs     DE
# 8      Adventure,Drama,Romance        12                   Na Estrada     BR
# 9      Adventure,Drama,Romance        13                     W drodze     PL
# 10     Adventure,Drama,Romance        14            Pela Estrada Fora     PT
# 11     Adventure,Drama,Romance        15                  On the Road    NaN
# 12     Adventure,Drama,Romance        16                      По пътя     BG
# 13     Adventure,Drama,Romance        17                    Sto dromo     GR
# 14     Adventure,Drama,Romance        18                         Úton     HU
# 15     Adventure,Drama,Romance        19                    Ba'drahim     IL
# 16     Adventure,Drama,Romance         1                 Sur la route     CA
# 17     Adventure,Drama,Romance        20                 En el camino     UY
# 18     Adventure,Drama,Romance        21              En la carretera     ES
# 19     Adventure,Drama,Romance        22                      Na putu     RS
# 20     Adventure,Drama,Romance        23                     Na cesti     SI
# 21     Adventure,Drama,Romance        24                       Kelyje     LT
# 22     Adventure,Drama,Romance        25       Matkalla - On the Road     FI
# 23     Adventure,Drama,Romance        26                      Pe drum     RO
# 24     Adventure,Drama,Romance        27                     Na ceste     CZ
# 25     Adventure,Drama,Romance        28                 Sur la route     FR
# 26     Adventure,Drama,Romance         2                    На дороге     RU
# 27     Adventure,Drama,Romance         3                         Teel     EE
# 28     Adventure,Drama,Romance         4                    Στο δρόμο     GR
# 29     Adventure,Drama,Romance         5                     Matkalla     FI
# ...                        ...       ...                          ...    ...
# 54704                    Drama         3                    Operation    XWW
# 54705                    Drama         4           The Spy Gone North    XWW
# 54706                    Drama         5           The Spy Gone North     AU
# 54707                    Drama         6           The Spy Gone North     NZ
# 54708                    Drama         7                      Gongjak    NaN
# 54709                    Drama         8                      Gongjak     KR
# 54710                    Drama         9           The Spy Gone North     FR
# 54711                    Drama         1                  A camareira     BR
# 54712                    Drama         2              The Chambermaid    XWW
# 54713                    Drama         3                 La camarista     FR
# 54714                    Drama         4                    Kambarine     LT
# 54715                    Drama         5                 La camarista     MX
# 54716                    Drama         6                 La camarista    NaN
# 54717                  Romance         1        Chao shi kong tong ju     CN
# 54718                  Romance         2     How Long Will I Love You     HK
# 54719                  Romance         3        Chao shi kong tong ju    NaN
# 54720                  Romance         4       How Long Will I Love U    XWW
# 54721                    Drama         1              Helicopter Eela    NaN
# 54722                    Drama         2                         Eela    NaN
# 54723                    Drama         3              Helicopter Eela     IN
# 54724            Drama,Romance         1               Ni hao, Zhihua    NaN
# 54725            Drama,Romance         2               Ni hao, Zhihua     CN
# 54726            Drama,Romance         3                  Last Letter    XWW
# 54727        Documentary,Music         1           Выжги сцену: Фильм     RU
# 54728        Documentary,Music         2    Burn the Stage: The Movie    NaN
# 54729        Documentary,Music         3    Burn The Stage. The movie     ES
# 54730        Documentary,Music         4    Burn the Stage: The Movie     KR
# 54731        Documentary,Music         5    Burn the Stage: The Movie     AR
# 54732        Documentary,Music         6  Burn the stage: La película     PE
# 54733        Documentary,Music         7            Sân Khâu Ánh Sáng     VN
#
#       language        types                        attributes  \
# 0          NaN     original                               NaN
# 1          NaN          NaN                               NaN
# 2          NaN          NaN                               NaN
# 3           en      working                               NaN
# 4           en      working                               NaN
# 5          NaN          NaN                               NaN
# 6          NaN  imdbDisplay                               NaN
# 7          NaN  imdbDisplay                               NaN
# 8          NaN  imdbDisplay                               NaN
# 9          NaN  imdbDisplay                               NaN
# 10         NaN  imdbDisplay                               NaN
# 11         NaN     original                               NaN
# 12          bg          NaN                               NaN
# 13         NaN          NaN  transliterated ISO-LATIN-1 title
# 14         NaN  imdbDisplay                               NaN
# 15          he  imdbDisplay                               NaN
# 16          fr  imdbDisplay                               NaN
# 17         NaN          NaN        original subtitled version
# 18         NaN  imdbDisplay                               NaN
# 19         NaN          NaN                               NaN
# 20         NaN  imdbDisplay                               NaN
# 21         NaN  imdbDisplay                               NaN
# 22         NaN          NaN                     DVD box title
# 23         NaN  imdbDisplay                               NaN
# 24         NaN  imdbDisplay                               NaN
# 25         NaN  imdbDisplay                               NaN
# 26         NaN          NaN                               NaN
# 27         NaN  imdbDisplay                               NaN
# 28         NaN          NaN                               NaN
# 29         NaN  imdbDisplay                               NaN
# ...        ...          ...                               ...
# 54704       en      working                               NaN
# 54705       en  imdbDisplay                               NaN
# 54706      NaN          NaN                  theatrical title
# 54707       en          NaN                  theatrical title
# 54708      NaN     original                               NaN
# 54709      NaN          NaN                               NaN
# 54710      NaN          NaN                  theatrical title
# 54711      NaN     festival                               NaN
# 54712       en  imdbDisplay                               NaN
# 54713      NaN  imdbDisplay                               NaN
# 54714      NaN  imdbDisplay                               NaN
# 54715      NaN          NaN                               NaN
# 54716      NaN     original                               NaN
# 54717      NaN          NaN                               NaN
# 54718       en          NaN              alternative spelling
# 54719      NaN     original                               NaN
# 54720       en  imdbDisplay                               NaN
# 54721      NaN     original                               NaN
# 54722      NaN      working                               NaN
# 54723      NaN          NaN                               NaN
# 54724      NaN     original                               NaN
# 54725      NaN          NaN                               NaN
# 54726       en  imdbDisplay                               NaN
# 54727      NaN          NaN                               NaN
# 54728      NaN     original                               NaN
# 54729      NaN  imdbDisplay                               NaN
# 54730      NaN          NaN                               NaN
# 54731      NaN  imdbDisplay                               NaN
# 54732      NaN  imdbDisplay                               NaN
# 54733      NaN  imdbDisplay                               NaN
#
#        is_original_title     studio  domestic_gross  foreign_gross  year  \
# 0                    1.0    Relbig.       1100000.0            0.0  2016
# 1                    0.0    Relbig.       1100000.0            0.0  2016
# 2                    0.0    Relbig.       1100000.0            0.0  2016
# 3                    0.0    Relbig.       1100000.0            0.0  2016
# 4                    0.0    Relbig.       1100000.0            0.0  2016
# 5                    0.0    Relbig.       1100000.0            0.0  2016
# 6                    0.0        IFC        744000.0      8000000.0  2012
# 7                    0.0        IFC        744000.0      8000000.0  2012
# 8                    0.0        IFC        744000.0      8000000.0  2012
# 9                    0.0        IFC        744000.0      8000000.0  2012
# 10                   0.0        IFC        744000.0      8000000.0  2012
# 11                   1.0        IFC        744000.0      8000000.0  2012
# 12                   0.0        IFC        744000.0      8000000.0  2012
# 13                   0.0        IFC        744000.0      8000000.0  2012
# 14                   0.0        IFC        744000.0      8000000.0  2012
# 15                   0.0        IFC        744000.0      8000000.0  2012
# 16                   0.0        IFC        744000.0      8000000.0  2012
# 17                   0.0        IFC        744000.0      8000000.0  2012
# 18                   0.0        IFC        744000.0      8000000.0  2012
# 19                   0.0        IFC        744000.0      8000000.0  2012
# 20                   0.0        IFC        744000.0      8000000.0  2012
# 21                   0.0        IFC        744000.0      8000000.0  2012
# 22                   0.0        IFC        744000.0      8000000.0  2012
# 23                   0.0        IFC        744000.0      8000000.0  2012
# 24                   0.0        IFC        744000.0      8000000.0  2012
# 54705  5.010000e-04        501000.0
# 54706  5.010000e-04        501000.0
# 54707  5.010000e-04        501000.0
# 54708  5.010000e-04        501000.0
# 54709  5.010000e-04        501000.0
# 54710  5.010000e-04        501000.0
# 54711  3.000000e-07           300.0
# 54712  3.000000e-07           300.0
# 54713  3.000000e-07           300.0
# 54714  3.000000e-07           300.0
# 54715  3.000000e-07           300.0
# 54716  3.000000e-07           300.0
# 54717  8.284700e-02      82847000.0
# 54718  8.284700e-02      82847000.0
# 54719  8.284700e-02      82847000.0
# 54720  8.284700e-02      82847000.0
# 54721  7.200000e-05         72000.0
# 54722  7.200000e-05         72000.0
# 54723  7.200000e-05         72000.0
# 54724  1.810000e-04        181000.0
# 54725  1.810000e-04        181000.0
# 54726  1.810000e-04        181000.0
# 54727  2.030000e-02      20300000.0
# 54728  2.030000e-02      20300000.0
# 54729  2.030000e-02      20300000.0
# 54730  2.030000e-02      20300000.0
# 54731  2.030000e-02      20300000.0
# 54732  2.030000e-02      20300000.0
# 54733  2.030000e-02      20300000.0
#
# [54734 rows x 20 columns]

# %%
g = sns.barplot(data=special_attributes, x='total_gross', y=special_attributes.index)

# for i, r in special_attributes.iterrows():
#     g.text(s=round(r.total_gross, 2), x=r.name, y=r.tip)

plt.title("Special Attributes by Total Gross")
plt.xlabel("Total Gross (billions)")
plt.ylabel("Special Attributes")

plt.show()

# %% [markdown]
# #### Analysis:
#
# To further support our previous recommendation, we present the above graph. From it, we can see that the special attribute that accounts for the highest total gross is 3D visual enhancement at over 80 billion dollars. While IMAX versions are not so proffitable, they are ranked 12th on the list, and account for more than 10 billion dollars.
#
# Given these results, our recommendation stands that there is substantial opportunity for profit in visually enhanced projects, and that Microsoft is in a unique position to offer groundbreaking viewing experiences in this area.

# %%
special_attributes.head()
# Out:
#                                   Unnamed: 0  start_year  runtime_minutes  \
# attributes
# 3-D version                          4572522      348546          19378.0
# transliterated ISO-LATIN-1 title     8340814      837091          45443.0
# original subtitled version          14622779      868462          47285.0
# dubbed version                       3705559      328101          16678.0
# fake working title                   1288256      116779           7172.0
#
#                                   ordering  is_original_title  domestic_gross  \
# attributes
# 3-D version                           3167                0.0    3.181957e+10
# transliterated ISO-LATIN-1 title      7129                0.0    2.565936e+10
# original subtitled version            6193                0.0    1.822751e+10
# dubbed version                        2392                0.0    1.214369e+10
# fake working title                     952                0.0    1.254795e+10
#
#                                   foreign_gross    year  total_gross  \
# attributes
# 3-D version                        5.113838e+10  348554    82.957956
# transliterated ISO-LATIN-1 title   4.088712e+10  837166    66.546477
# original subtitled version         2.505882e+10  868547    43.286334
# dubbed version                     2.232917e+10  328136    34.472856
# fake working title                 1.708879e+10  116780    29.636739
#
#                                   gross_unscaled
# attributes
# 3-D version                         8.295796e+10
# transliterated ISO-LATIN-1 title    6.654648e+10
# original subtitled version          4.328633e+10
# dubbed version                      3.447286e+10
# fake working title                  2.963674e+10

# %%
three_d = final_df[final_df.attributes == '3-D version']
split_3d = three_d
three_d_per_year = three_d.groupby('year').size()
three_d = three_d.groupby('year').sum()
three_d['films_per_year'] = three_d_per_year

three_d['gross_by_num_films'] = three_d.total_gross / three_d.films_per_year

three_d

# imax = final_df[final_df.attributes == 'IMAX version']

# imax = imax.groupby('year').sum()

# imax
# Out:
#       Unnamed: 0  start_year  runtime_minutes  ordering  is_original_title  \
# year
# 2010       55592       18090            821.0       239                0.0
# 2011      138208       30165           1633.0       300                0.0
# 2012      185044       26154           1229.0       246                0.0
# 2013      142618       24156           1452.0       217                0.0
# 2014      415326       30210           1686.0       224                0.0
# 2015      680824       60450           3425.0       523                0.0
# 2016     1199518       66528           3761.0       599                0.0
# 2017     1052481       58489           3373.0       546                0.0
# 2018      702911       34304           1998.0       273                0.0
#
#       domestic_gross  foreign_gross  total_gross  gross_unscaled  \
# year
# 2010    9.970000e+08   1.755100e+09     2.752100    2.752100e+09
# 2011    1.908900e+09   4.616900e+09     6.525800    6.525800e+09
# 2012    1.590378e+09   3.912282e+09     5.502660    5.502660e+09
# 2013    2.728100e+09   4.698800e+09     7.426900    7.426900e+09
# 2014    2.168392e+09   4.750400e+09     6.918792    6.918792e+09
# 2015    7.350413e+09   6.836600e+09    14.187013    1.418701e+10
# 2016    6.432475e+09   1.089140e+10    17.323875    1.732388e+10
# 2017    4.916700e+09   8.743600e+09    13.660300    1.366030e+10
# 2018    3.727216e+09   4.933300e+09     8.660516    8.660516e+09
#
#       films_per_year  gross_by_num_films
# year
# 2010               9            0.305789
# 2011              15            0.435053
# 2012              13            0.423282
# 2013              12            0.618908
# 2014              15            0.461253
# 2015              30            0.472900
# 2016              33            0.524966
# 2017              29            0.471045
# 2018              17            0.509442

# %%
sns.lineplot(data=three_d.reset_index(), x='year', y='total_gross')
plt.title("Total Gross of 3D films per Year")
plt.show()
sns.lineplot(data=three_d.reset_index(), x='year', y='gross_by_num_films')
plt.title("Average gross per 3D Film per Year")
plt.show()

# %% [markdown]
# #### Analysis:
#
# (2nd graph)
#
# Besides an anomalous spike in generated revenue in 2013, 3D films have experience a significant rise in gross profits since 2010, and have been holding relatively steady for the last 4 years. Given this trend and perceived staying power, the recommendation holds that Microsoft look into ways to use their proprietary technology to visually enhance their productions.

# %%
imax = final_df[final_df.attributes == 'IMAX version']
imax = imax.groupby('primary_title').sum()

f = plt.figure(figsize=(10, 4))

split_3d = split_3d.groupby('primary_title').sum()

sns.distplot(a=split_3d.total_gross, bins=50, hist_kws=dict(alpha=1))
sns.distplot(a=imax.total_gross, bins=50, hist_kws=dict(alpha=0.5))
sns.distplot(a=final_df.total_gross, bins=50, hist_kws=dict(alpha=0.25))

plt.legend(['3d', 'IMAX', "Standard"])

plt.xlabel("Total Gross (billions)")
plt.ylabel('Count')
plt.xlim([0, 1.5])
plt.title("Distribution of Gross Revenue by Visual Enhancement")
plt.show()

# %%
final_df.sort_values('total_gross')
# Out:
#        Unnamed: 0   title_id            primary_title  \
# 29720       29720  tt1986953               Storage 24
# 29724       29724  tt1986953               Storage 24
# 29723       29723  tt1986953               Storage 24
# 29722       29722  tt1986953               Storage 24
# 49796                   Horror         7                             Satânico
# 6021                  Thriller         8                          Premonición
# 6022                  Thriller         9              2:22 - Encontro Marcado
# 6011                  Thriller        12                                 2:22
# 6019                  Thriller         6                                 2:22
# 6018                  Thriller         5                     La hora señalada
# 6012                  Thriller        13      2:22 - Il destino è già scritto
# 6017                  Thriller         4                 2:22 - Hora Fatídica
# 6016                  Thriller         3                     2:22 Premonición
# 6015                  Thriller         2                                 2:22
# 6020                  Thriller         7          2:22 - Párhuzamos vonzalmak
# 6009                  Thriller        10            2:22 - Zeit für die Liebe
# ...                        ...       ...                                  ...
# 36739  Action,Adventure,Sci-Fi         6              Avengers 2: Vek Ultrona
# 36738  Action,Adventure,Sci-Fi         5  Razbunatorii: Sub semnul lui Ultron
# 36737  Action,Adventure,Sci-Fi         4       Osvetnici 2: Vladavina Ultrona
# 36736  Action,Adventure,Sci-Fi        41               Мстители: Эра Альтрона
# 36735  Action,Adventure,Sci-Fi        40   Los Vengadores 2: La Era De Ultron
# 36734  Action,Adventure,Sci-Fi         3              Avengers: Age of Ultron
# 36733  Action,Adventure,Sci-Fi        39               Osvetnici: Era Altrona
# 36732  Action,Adventure,Sci-Fi        38             Bosszúállók: Ultron kora
# 36731  Action,Adventure,Sci-Fi        37             Qisasçilar: Ultron Dövrü
# 36730  Action,Adventure,Sci-Fi        36                        Age of Ultron
# 36729  Action,Adventure,Sci-Fi        35             Yenilmezler: Ultron Çagi
# 36728  Action,Adventure,Sci-Fi        34           Maščevalci: Ultronova doba
# 36727  Action,Adventure,Sci-Fi        33            Vingadores: Era de Ultron
# 36726  Action,Adventure,Sci-Fi        32               Avengers: Czas Ultrona
# 36712  Action,Adventure,Sci-Fi         1     Os Vingadores 2: A Era de Ultron
# 36713  Action,Adventure,Sci-Fi        20        Εκδικητές: Η εποχή του Ultron
# 36714  Action,Adventure,Sci-Fi        21              Tasujad: Ultroni ajastu
# 36715  Action,Adventure,Sci-Fi        22          Atriebeji: Ultrona laikmets
# 36716  Action,Adventure,Sci-Fi        23       Отмъстителите: Ерата на Ултрон
# 36717  Action,Adventure,Sci-Fi        24              Avengers: Age of Ultron
# 36710  Action,Adventure,Sci-Fi        18              Avengers: Era de Ultrón
# 36718  Action,Adventure,Sci-Fi        25             Avengers: L'ère d'Ultron
# 36720  Action,Adventure,Sci-Fi        27                       The Avengers 2
# 36721  Action,Adventure,Sci-Fi        28           Avengers: La era de Ultrón
# 36722  Action,Adventure,Sci-Fi        29         Vengadores: La era de Ultrón
# 36723  Action,Adventure,Sci-Fi         2          Avengers 2: Epoka e Ultrona
# 36724  Action,Adventure,Sci-Fi        30                          After Party
# 36725  Action,Adventure,Sci-Fi        31              Avengers: De Che Ultron
# 36719  Action,Adventure,Sci-Fi        26              Avengers: Era de Ultrón
# 36703  Action,Adventure,Sci-Fi        11              Avengers: Era de Ultrón
#
#       region language        types                  attributes  \
# 29720     RU      NaN          NaN                         NaN
# 29724     EE      NaN  imdbDisplay                         NaN
# 29723    NaN      NaN     original                         NaN
# 29722     GB      NaN          NaN                         NaN
# 29721     TR       tr  imdbDisplay                         NaN
# 49790    NaN      NaN     original                         NaN
# 54716    NaN      NaN     original                         NaN
# 54715     MX      NaN          NaN                         NaN
# 54714     LT      NaN  imdbDisplay                         NaN
# 54713     FR      NaN  imdbDisplay                         NaN
# 54712    XWW       en  imdbDisplay                         NaN
# 49791     MX      NaN  imdbDisplay                         NaN
# 54711     BR      NaN     festival                         NaN
# 49797     AR      NaN  imdbDisplay                         NaN
# 49792     UY      NaN          NaN  original subtitled version
# 49793     CL      NaN  imdbDisplay                         NaN
# 49794     RU      NaN          NaN                         NaN
# 49795     US      NaN          NaN                         NaN
# 49796     BR      NaN  imdbDisplay                         NaN
# 6021      MX      NaN  imdbDisplay                         NaN
# 6022      BR      NaN  imdbDisplay                         NaN
# 6011      RU      NaN          NaN                         NaN
# 6019      AU      NaN          NaN                         NaN
# 6018      ES      NaN  imdbDisplay                         NaN
# 6012      IT      NaN  imdbDisplay                         NaN
# 6017      PT      NaN  imdbDisplay                         NaN
# 6016      PE      NaN  imdbDisplay                         NaN
# 6015      TR       tr  imdbDisplay                         NaN
# 6020      HU      NaN  imdbDisplay                         NaN
# 6009      DE      NaN  imdbDisplay                         NaN
# ...      ...      ...          ...                         ...
# 36739     SK      NaN  imdbDisplay                         NaN
# 36738     RO      NaN  imdbDisplay                         NaN
# 36737     HR      NaN  imdbDisplay                         NaN
# 36736     RU      NaN          NaN                         NaN
# 36735     VE      NaN  imdbDisplay                         NaN
# 36734     IT      NaN  imdbDisplay                         NaN
# 36733     RS      NaN  imdbDisplay                         NaN
# 36732     HU      NaN  imdbDisplay                         NaN
# 36731     AZ      NaN  imdbDisplay                         NaN
# 36730    XWW       en          NaN                 short title
# 36729     TR       tr  imdbDisplay                         NaN
# 36728     SI      NaN          NaN                         NaN
# 36727     BR      NaN  imdbDisplay                         NaN
# 36726     PL      NaN  imdbDisplay                         NaN
# 36712     BR      NaN  alternative                         NaN
# 36713     GR      NaN          NaN                         NaN
# 36714     EE      NaN  imdbDisplay                         NaN
# 36715     LV      NaN  imdbDisplay                         NaN
# 36716     BG       bg          NaN                         NaN
# 36717    NaN      NaN     original                         NaN
# 36710     AR      NaN  imdbDisplay                         NaN
# 36718     FR      NaN  imdbDisplay                         NaN
# 36720     US      NaN      working                         NaN
# 36721     UY      NaN          NaN                 3-D version
# 36722     ES      NaN  imdbDisplay                         NaN
# 36723     AL      NaN  imdbDisplay                         NaN
# 36724     US      NaN          NaN          fake working title
# 36725     VN      NaN  imdbDisplay                         NaN
# 36719     CL      NaN  imdbDisplay                         NaN
# 36703     PE      NaN  imdbDisplay                         NaN
#
#        is_original_title studio  domestic_gross  foreign_gross  year  \
# 29720                0.0  Magn.           100.0            0.0  2013
# 29724                0.0  Magn.           100.0            0.0  2013
# 29723                1.0  Magn.           100.0            0.0  2013
# 29722                0.0  Magn.           100.0            0.0  2013
# 29721                0.0  Magn.           100.0            0.0  2013
# 49790                1.0  Magn.           300.0            0.0  2016
# 54716                1.0     FM           300.0            0.0  2015
# 49790  3.000000e-07    3.000000e+02
# 54716  3.000000e-07    3.000000e+02
# 54715  3.000000e-07    3.000000e+02
# 54714  3.000000e-07    3.000000e+02
# 54713  3.000000e-07    3.000000e+02
# 54712  3.000000e-07    3.000000e+02
# 49791  3.000000e-07    3.000000e+02
# 54711  3.000000e-07    3.000000e+02
# 49797  3.000000e-07    3.000000e+02
# 49792  3.000000e-07    3.000000e+02
# 49793  3.000000e-07    3.000000e+02
# 49794  3.000000e-07    3.000000e+02
# 49795  3.000000e-07    3.000000e+02
# 49796  3.000000e-07    3.000000e+02
# 6021   4.000000e-07    4.000000e+02
# 6022   4.000000e-07    4.000000e+02
# 6011   4.000000e-07    4.000000e+02
# 6019   4.000000e-07    4.000000e+02
# 6018   4.000000e-07    4.000000e+02
# 6012   4.000000e-07    4.000000e+02
# 6017   4.000000e-07    4.000000e+02
# 6016   4.000000e-07    4.000000e+02
# 6015   4.000000e-07    4.000000e+02
# 6020   4.000000e-07    4.000000e+02
# 6009   4.000000e-07    4.000000e+02
# ...             ...             ...
# 36739  1.405400e+00    1.405400e+09
# 36738  1.405400e+00    1.405400e+09
# 36737  1.405400e+00    1.405400e+09
# 36736  1.405400e+00    1.405400e+09
# 36735  1.405400e+00    1.405400e+09
# 36734  1.405400e+00    1.405400e+09
# 36733  1.405400e+00    1.405400e+09
# 36732  1.405400e+00    1.405400e+09
# 36731  1.405400e+00    1.405400e+09
# 36730  1.405400e+00    1.405400e+09
# 36729  1.405400e+00    1.405400e+09
# 36728  1.405400e+00    1.405400e+09
# 36727  1.405400e+00    1.405400e+09
# 36726  1.405400e+00    1.405400e+09
# 36712  1.405400e+00    1.405400e+09
# 36713  1.405400e+00    1.405400e+09
# 36714  1.405400e+00    1.405400e+09
# 36715  1.405400e+00    1.405400e+09
# 36716  1.405400e+00    1.405400e+09
# 36717  1.405400e+00    1.405400e+09
# 36710  1.405400e+00    1.405400e+09
# 36718  1.405400e+00    1.405400e+09
# 36720  1.405400e+00    1.405400e+09
# 36721  1.405400e+00    1.405400e+09
# 36722  1.405400e+00    1.405400e+09
# 36723  1.405400e+00    1.405400e+09
# 36724  1.405400e+00    1.405400e+09
# 36725  1.405400e+00    1.405400e+09
# 36719  1.405400e+00    1.405400e+09
# 36703  1.405400e+00    1.405400e+09
#
# [54734 rows x 20 columns]

# %%
enhanced_attributes = final_df[final_df.attributes.str.contains("title|alt|promo")==False]
enhanced_attributes.attributes.value_counts()
# Out:
# 3-D version                173
# dubbed version             163
# IMAX version                22
# director's cut               5
# cut version                  5
# recut version                4
# longer version               3
# short version                2
# correct transliteration      1
# Name: attributes, dtype: int64

# %%
enhanced_attributes = enhanced_attributes.groupby('attributes').sum().sort_values('total_gross', ascending=False)

# %%
sns.barplot(data=enhanced_attributes, x='total_gross', y=enhanced_attributes.index)
plt.xticks(rotation=0.5)
plt.show()

# %% [markdown]
# #### Analysis:
#
# When you get rid of all the bogus attributes listed, you can see that 3d versions far out perform other attributes. IMAX also lands in the top 3 with a total revenue of over 10 billion dollars
