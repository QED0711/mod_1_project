# %%
# !dir ./data/
# Out:
# Parameter format not correct - "data".

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

from cleaning_scripts import *

# pd.set_option('display.max_rows', None)

# %%
basics_df = pd.read_csv('./data/imdb.title.basics.csv.gz')
gross_df = pd.read_csv('./data/bom.movie_gross.csv.gz')
akas_df = pd.read_csv('./data/imdb.title.akas.csv.gz')

# %% [markdown]
# # HEADS

# %%
print(akas_df.shape)
akas_df.head()
# Out:
# (331703, 8)
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
print(gross_df.shape)
gross_df.head()
# Out:
# (3387, 5)
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
print(basics_df.shape)
basics_df.head()
# Out:
# (146144, 6)
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %% [markdown]
# # MERGES

# %% [markdown]
# ### Merge basics with akas on title id

# %%
# Change tcont to titl_id
basics_df.rename(columns={'tconst': 'title_id'}, inplace=True)

common_id_df = basics_df.merge(akas_df, on='title_id', how='inner')
print(common_id_df.shape)
# Out:
# (331703, 13)

# %% [markdown]
# ### merge gross with common

# %%
gross_df.rename(columns={'title': 'primary_title'}, inplace=True)
final_df = common_id_df.merge(gross_df, on='primary_title', how='inner')
final_df.shape
# Out:
# (54734, 17)

# %%
final_df.foreign_gross = pd.to_numeric(final_df.foreign_gross, errors='coerce')
final_df.foreign_gross.fillna(0.0, inplace=True)
final_df.foreign_gross.isna().any()
# Out:
# False

# %%
final_df.foreign_gross = pd.to_numeric(final_df.foreign_gross, errors='coerce')
final_df.foreign_gross = final_df.foreign_gross.dropna()

# create total_gross column
final_df['total_gross'] = final_df.domestic_gross + final_df.foreign_gross
# replace na values with the domistic or foreign (whichever is not na)
final_df.total_gross.fillna(final_df.domestic_gross, inplace=True)
final_df.total_gross.fillna(final_df.foreign_gross, inplace=True)

# drop repeated movie listings that resulted in the same total gross
unique_titles_df = final_df.drop_duplicates(subset=['primary_title', 'total_gross'])
# final_df.shape

# print(final_df.domestic_gross.isna().sum())
# print(final_df.foreign_gross.isna().sum())

# %% [markdown]
# # PLOTS

# %% [markdown]
# ### Total Gross by Labeled Genre

# %%
performant_genres = unique_titles_df.groupby("genres").sum().sort_values('total_gross', ascending=False)[0:10]


sns.barplot(data=performant_genres, y=performant_genres.index, x='total_gross', orient='h')

plt.xlabel('Total Gross (millions)')
plt.title("Total Gross by Top 10 Genres")
# Out:
# Text(0.5, 1.0, 'Total Gross by Top 10 Genres')

# %% [markdown]
# ### Top Genres by Appearance in performant genres

# %%
# def parse_genres(genre_series = []):
#     unique_genres = []
#     for g in genre_series:
#         if type(g) == str:
#             for individual_g in g.split(','):
#                 if not individual_g in unique_genres:
#                     unique_genres.append(individual_g)
#     return unique_genres

# %%
# def genre_count(genres, df):
#     genre_dict = {}
#     for long_genre in df.genres:
#         for short_genre in genres:
#             if short_genre in long_genre:
#                 if short_genre in genre_dict:
#                     genre_dict[short_genre] += 1
#                 else:
#                     genre_dict[short_genre] = 1
#     return genre_dict

# %%
subgenres = get_subgenres(performant_genres.reset_index().genres)
subgenres
# Out:
# ['Action',
#  'Adventure',
#  'Sci-Fi',
#  'Animation',
#  'Comedy',
#  'Fantasy',
#  'Thriller',
#  'Drama',
#  'Crime']

# %%
top_subgenres = subgenre_counter(subgenres, performant_genres.reset_index())
top_subgenres
# Out:
# {'Action': 8,
#  'Adventure': 7,
#  'Sci-Fi': 1,
#  'Animation': 2,
#  'Comedy': 3,
#  'Fantasy': 1,
#  'Thriller': 3,
#  'Drama': 1,
#  'Crime': 1}

# %%
top_genres_df = pd.DataFrame(top_subgenres.items())
top_genres_df.columns = ["Genre", "Count"]
top_genres_df = top_genres_df.sort_values('Count', ascending=False)
sns.barplot(data=top_genres_df, x="Count", y='Genre')
plt.xlabel("Appearances in Top 10")
plt.ylabel("Subgenre")
plt.title("Subgenre Counts from Top 10 Genres")
# Out:
# Text(0.5, 1.0, 'Subgenre Counts from Top 10 Genres')

# %% [markdown]
# #### INSIGHTS:
#
# We can plainly see that Action and Adventure genres outperform all other genres by a wide margin. Recommendation is that MS Focus efforts on these genres to maximize impact in the product space.

# %% [markdown]
# # PARSING TECH MOVIES

# %%
final_df.shape
# Out:
# (54734, 18)

# %%
tech_movies = final_df[final_df.attributes.isin(['3-D version', 'IMAX version'])]

top_tech_movies_df = tech_movies.groupby('primary_title').sum().sort_values('total_gross', ascending=False)[0:10]

tech_movies_by_genre_df = tech_movies.groupby('genres').sum().sort_values('total_gross', ascending=False)

top_tech_movies_df.head()
# Out:
#                                     start_year  runtime_minutes  ordering  \
# primary_title
# Captain America: Civil War                6048            441.0        71
# Jurassic World                           10075            620.0        81
# Zootopia                                  6048            324.0        52
# Transformers: Dark of the Moon            4022            308.0        40
# Madagascar 3: Europe's Most Wanted        6036            279.0        53
#
#                                     is_original_title  domestic_gross  \
# primary_title
# Captain America: Civil War                        0.0    1.224300e+09
# Jurassic World                                    0.0    3.261500e+09
# Zootopia                                          0.0    1.023900e+09
# Transformers: Dark of the Moon                    0.0    7.048000e+08
# Madagascar 3: Europe's Most Wanted                0.0    6.492000e+08
#
#                                     foreign_gross   year   total_gross
# primary_title
# Captain America: Civil War           2.235600e+09   6048  3.459900e+09
# Jurassic World                       0.000000e+00  10075  3.261500e+09
# Zootopia                             2.047500e+09   6048  3.071400e+09
# Transformers: Dark of the Moon       1.542800e+09   4022  2.247600e+09
# Madagascar 3: Europe's Most Wanted   1.591500e+09   6036  2.240700e+09

# %%
sns.barplot(data=tech_movies_by_genre_df[0:10], x='total_gross', y=tech_movies_by_genre_df[0:10].index)

# %% [markdown]
# #### INSIGHTS:
#
# the top genres of the tech movies looks very similar to the top genres overall. Recommendation stands that MS invest in Action and Adventure genres in their visually enhanced movies

# %%
sns.barplot(data=top_tech_movies_df, x='total_gross', y=top_tech_movies_df.index)
plt.ylabel("Movie")
plt.xlabel("Total Gross")
plt.title("Top 10 Grossing Movies with Enhanced Visual Element")
# Out:
# Text(0.5, 1.0, 'Top 10 Grossing Movies with Enhanced Visual Element')

# %% [markdown]
# #### INSIGHTS:
#
# This list of top 10 movies with visual enhancements (3D, IMAX) can serve as a model for MS's new studio.

# %% [markdown]
# ### Getting gross of genres

# %%
# get a list of uniue genres
unique_genres = parse_genres(final_df.genres)
genres_df = pd.DataFrame(columns=['genre', 'gross'])



# genres_df = genres_df.append({'genre': 'Action', 'gross': 500}, ignore_index=True)

genres_df.groupby('genre').sum()
# genres_df
# genres_df = pd.DataFrame(parse_genres(genres))
# genres_df.rename(columns={0: 'genre'}, inplace=True)

# genres = final_df.genres

# for i, g in enumerate(genres):
#     simple_genre = genres_df.genre
#     for j, sg in enumerate(simple_genre):
#         if sg in g:
#             print(i, j)
# Out:
# Empty DataFrame
# Columns: [gross]
# Index: []

# %%
final_plot = final_df[(final_df.region == 'US') & (final_df.attributes.isin(['3-D version', 'IMAX version']))].head(33)
final_plot.sort_values('domestic_gross', inplace=True)

final_plot.shape
# Out:
# (33, 18)

# %%
final_plot.foreign_gross = pd.to_numeric(final_plot.foreign_gross, errors='coerce')
final_plot.foreign_gross = final_plot.foreign_gross.dropna()

final_plot['total_gross'] = final_plot.domestic_gross + final_plot.foreign_gross
final_plot['first_genre'] = final_plot.genres.apply(lambda x: x.split(',')[0])

# %% [markdown]
# # PLOTS (OLD)

# %% [markdown]
# ### Genre Plot
#
# This plot shows us that, of the 3d and imax movies, action outperforms its nearest competator by nearly 60%. Recommendation - provide technical alternatives (holo lens, xbox, etc.) for action movies to gain a unique place in the product sphere.

# %%
grouped_genres = final_plot.groupby('first_genre').sum()
grouped_genres.plot.bar(y='total_gross')

# %%
final_plot.sort_values(by='total_gross').plot.bar(x='foreign_gross', y='total_gross')

# %%
common_id_df[common_id_df.attributes.isin(['3-D version', 'IMAX version'])]
# Out:
#          title_id                                primary_title  \
# 304     tt0369610                               Jurassic World
# 305     tt0369610                               Jurassic World
# 306     tt0369610                               Jurassic World
# 337     tt0369610                               Jurassic World
# 338     tt0369610                               Jurassic World
# 545     tt0401729                                  John Carter
# 825     tt0433035                                   Real Steel
# 879     tt0435761                                  Toy Story 3
# 888     tt0435761                                  Toy Story 3
# 1090    tt0448115                                      Shazam!
# 1159    tt0451279                                 Wonder Woman
# 1214    tt0454876                                   Life of Pi
# 1884    tt0478970                                      Ant-Man
# 1907    tt0478970                                      Ant-Man
# 1912    tt0478970                                      Ant-Man
# 2448    tt0765446                     Escape from Planet Earth
# 2544    tt0770828                                 Man of Steel
# 3049    tt0800369                                         Thor
# 3476    tt0816462                          Conan the Barbarian
# 3479    tt0816462                          Conan the Barbarian
# 3547    tt0816711                                  World War Z
# 3548    tt0816711                                  World War Z
# 3647    tt0822847                                       Priest
# 3724    tt0831387                                     Godzilla
# 3740    tt0831387                                     Godzilla
# 3781    tt0837562                           Hotel Transylvania
# 4014    tt0848228                                 The Avengers
# 4237    tt0872230                              My Soul to Take
# 4249    tt0872230                              My Soul to Take
# 4604    tt0892769                     How to Train Your Dragon
# ...           ...                                          ...
# 230725  tt4729560                        The Little Vampire 3D
# 230742  tt4729560                        The Little Vampire 3D
# 235458  tt4877122                              The Emoji Movie
# 235473  tt4877122                              The Emoji Movie
# 235691  tt4881806               Jurassic World: Fallen Kingdom
# 236737  tt4912910                Mission: Impossible - Fallout
# 240313  tt5007458                      The Royal Adelaide Show
# 240523  tt5013056                                      Dunkirk
# 241072  tt5029776  Rabbit School - Guardians of the Golden Egg
# 248837  tt5220122        Hotel Transylvania 3: Summer Vacation
# 250669  tt5269396                                 Sword Master
# 258555  tt5523010           The Nutcracker and the Four Realms
# 263145  tt5654164                                  Le Mans: 3D
# 265149  tt5715410                           The Son of Bigfoot
# 266740  tt5758778                                   Skyscraper
# 270095  tt5848272                    Ralph Breaks the Internet
# 271255  tt5884052                    Pokémon Detective Pikachu
# 280230  tt6139732                                      Aladdin
# 281714  tt6182908                                    Smallfoot
# 283702  tt6241270             Cinderella and the Secret Prince
# 289260  tt6428676                                  Wonder Park
# 289744  tt6447610                                   The Mirror
# 292975  tt6565702                                 Dark Phoenix
# 293175  tt6572702                               Monster Family
# 298303  tt6803476                       Oz Comic Con The Movie
# 312572  tt7403570                                    Two Tails
# 312596  tt7403614                                 The Big Trip
# 323520  tt8292676              Shimajiro and the Rainbow Oasis
# 323521  tt8292676              Shimajiro and the Rainbow Oasis
# 326656  tt8760684                                    Apollo 11
#
#                                       original_title  start_year  \
# 304                                   Jurassic World        2015
# 305                                   Jurassic World        2015
# 306                                   Jurassic World        2015
# 337                                   Jurassic World        2015
# 338                                   Jurassic World        2015
# 545                                      John Carter        2012
# 825                                       Real Steel        2011
# 879                                      Toy Story 3        2010
# 888                                      Toy Story 3        2010
# 1090                                         Shazam!        2019
# 1159                                    Wonder Woman        2017
# 1214                                      Life of Pi        2012
# 1884                                         Ant-Man        2015
# 1907                                         Ant-Man        2015
# 1912                                         Ant-Man        2015
# 2448                        Escape from Planet Earth        2013
# 2544                                    Man of Steel        2013
# 3049                                            Thor        2011
# 3476                             Conan the Barbarian        2011
# 3479                             Conan the Barbarian        2011
# 3547                                     World War Z        2013
# 3548                                     World War Z        2013
# 3647                                          Priest        2011
# 3724                                        Godzilla        2014
# 3740                                        Godzilla        2014
# 3781                              Hotel Transylvania        2012
# 4014                                    The Avengers        2012
# 4237                                 My Soul to Take        2010
# 4249                                 My Soul to Take        2010
# 4604                        How to Train Your Dragon        2010
# ...                                              ...         ...
# 230725                         The Little Vampire 3D        2017
# 230742                         The Little Vampire 3D        2017
# 235458                               The Emoji Movie        2017
# 235473                               The Emoji Movie        2017
# 235691                Jurassic World: Fallen Kingdom        2018
# 236737                 Mission: Impossible - Fallout        2018
# 240313                       The Royal Adelaide Show        2015
# 240523                                       Dunkirk        2017
# 241072  Die Häschenschule: Jagd nach dem goldenen Ei        2017
# 248837         Hotel Transylvania 3: Summer Vacation        2018
# 250669                           San shao ye de jian        2016
# 258555            The Nutcracker and the Four Realms        2018
# 263145                                   Le Mans: 3D        2016
# 265149                            The Son of Bigfoot        2017
# 266740                                    Skyscraper        2018
# 270095                     Ralph Breaks the Internet        2018
# 271255                     Pokémon Detective Pikachu        2019
# 280230                                       Aladdin        2019
# 281714                                     Smallfoot        2018
# 283702              Cinderella and the Secret Prince        2018
# 289260                                   Wonder Park        2019
# 289744                                       Mo jing        2015
# 292975                                  Dark Phoenix        2019
# 293175                                  Happy Family        2017
# 298303                        Oz Comic Con The Movie        2017
# 312572                                     Two Tails        2018
# 312596                                  The Big Trip        2019
# 323520               Shimajiro and the Rainbow Oasis        2017
# 323521               Shimajiro and the Rainbow Oasis        2017
# 326656                                     Apollo 11        2019
#
#         runtime_minutes                      genres  ordering  \
# 304               124.0     Action,Adventure,Sci-Fi        21
# 305               124.0     Action,Adventure,Sci-Fi        22
# 306               124.0     Action,Adventure,Sci-Fi        23
# 337               124.0     Action,Adventure,Sci-Fi         7
# 338               124.0     Action,Adventure,Sci-Fi         8
# 545               132.0     Action,Adventure,Sci-Fi        34
# 825               127.0         Action,Drama,Family         6
# 879               103.0  Adventure,Animation,Comedy        20
# 888               103.0  Adventure,Animation,Comedy        29
# 1090              132.0     Action,Adventure,Comedy         2
# 1159              141.0    Action,Adventure,Fantasy        26
# 1214              127.0     Adventure,Drama,Fantasy        23
# 1884              117.0     Action,Adventure,Comedy        10
# 1907              117.0     Action,Adventure,Comedy        31
# 1912              117.0     Action,Adventure,Comedy         7
# 2448               89.0  Adventure,Animation,Comedy         5
# 2544              143.0     Action,Adventure,Sci-Fi         5
# 3049              115.0    Action,Adventure,Fantasy        25
# 3476              113.0    Action,Adventure,Fantasy         4
# 3479              113.0    Action,Adventure,Fantasy         7
# 3547              116.0     Action,Adventure,Horror        37
# 3548              116.0     Action,Adventure,Horror         3
# 3647               87.0    Action,Adventure,Fantasy         9
# 3724              123.0     Action,Adventure,Sci-Fi        18
# 3740              123.0     Action,Adventure,Sci-Fi         8
# 3781               91.0     Animation,Comedy,Family        19
# 4014              143.0     Action,Adventure,Sci-Fi         7
# 4237              107.0     Horror,Mystery,Thriller        17
# 4249              107.0     Horror,Mystery,Thriller        28
# 4604               98.0  Action,Adventure,Animation         4
# ...                 ...                         ...       ...
# 230725             83.0  Adventure,Animation,Comedy        12
# 230742             83.0  Adventure,Animation,Comedy         2
# 235458             86.0  Adventure,Animation,Comedy        11
# 235473             86.0  Adventure,Animation,Comedy        25
# 235691            128.0     Action,Adventure,Sci-Fi        21
# 236737            147.0   Action,Adventure,Thriller        18
# 240313             55.0                 Documentary         3
# 240523            106.0        Action,Drama,History         8
# 241072             79.0  Adventure,Animation,Comedy        16
# 248837             97.0  Adventure,Animation,Comedy        12
# 250669            108.0                Action,Drama         1
# 258555             99.0    Adventure,Family,Fantasy        10
# 263145             90.0           Documentary,Sport         1
# 265149             92.0  Adventure,Animation,Comedy        14
# 266740            102.0   Action,Adventure,Thriller         4
# 270095            112.0  Adventure,Animation,Comedy        10
# 271255            104.0     Action,Adventure,Comedy        17
# 280230            128.0     Adventure,Comedy,Family        28
# 281714             96.0  Adventure,Animation,Comedy        19
# 283702             90.0  Adventure,Animation,Family         8
# 289260             85.0  Adventure,Animation,Comedy        25
# 289744              NaN                      Horror         1
# 292975            113.0     Action,Adventure,Sci-Fi        31
# 293175             93.0     Animation,Comedy,Family        35
# 298303             66.0                         NaN         3
# 312572             75.0  Adventure,Animation,Comedy        18
# 312596             90.0  Adventure,Animation,Comedy         6
# 323520              NaN  Action,Adventure,Animation         2
# 323521              NaN  Action,Adventure,Animation         3
# 326656             93.0         Documentary,History         5
#
#                                                     title region language  \
# 304                                     Jurassic World 3D     US      NaN
# 305                                     Jurassic World 3D     DE      NaN
# 306                                     Jurassic World 3D    XWW      NaN
# 337                                        Mundo Jurásico     UY      NaN
# 338                                     Jurassic World 3D     PL      NaN
# 545                         John Carter: Entre dos mundos     UY      NaN
# 825                       Real Steel: The IMAX Experience     US      NaN
# 879                                           Toy Story 3     UY      NaN
# 888                    Toy Story 3: An IMAX 3D Experience     US      NaN
# 1090                                              Shazam!     UY      NaN
# 1159                                      Mujer maravilla     UY      NaN
# 1214              Life of Pi: Una aventura extraordinaria     UY      NaN
# 1884                                           Ant-Man 3D     PL      NaN
# 1907                           Ant-Man: El hombre hormiga     UY      NaN
# 1912                                           Ant-Man 3D    XWW      NaN
# 2448                                   Héroes del espacio     UY      NaN
# 2544                                   El hombre de acero     UY      NaN
# 3049                                              Thor 3D     VE      NaN
# 3476                                    Conan, el bárbaro     UY      NaN
# 3479                                             Conan 3D     RO      NaN
# 3547                                     Guerra mundial Z     UY      NaN
# 3548                                Ziua Z: Apocalipsa 3D     RO      NaN
# 3647                                       El vengador 3D     VE      NaN
# 3724                                          Godzilla 3D     RO      NaN
# 3740                                             Godzilla     UY      NaN
# 3781                                   Hotel Transylvania     UY      NaN
# 4014                  The Avengers: An IMAX 3D Experience    XWW       en
# 4237                                   Ia sufletul meu 3D     RO      NaN
# 4249                                   My Soul to Take 3D     US      NaN
# 4604      How to Train Your Dragon: An IMAX 3D Experience     US      NaN
# ...                                                   ...    ...      ...
# 230725                               De Kleine Vampier 3D     NL      NaN
# 230742                                 El pequeño vampiro     UY      NaN
# 235458                                 Emoji, la película     UY      NaN
# 235473             Emoji filmul. Aventura zambaretilor 3D     RO      NaN
# 235691                     Jurassic World: El reino caído     UY      NaN
# 236737                      Misión imposible: Repercusión     UY       es
# 240313                         The Royal Adelaide Show 3D     AU      NaN
# 240523                       Dunkirk: The IMAX Experience     US      NaN
# 241072     Rabbit School - Guardians of the Golden Egg 3D    XWW      NaN
# 248837      Hotel Transylvania 3: Monstruos de vacaciones     UY      NaN
# 250669                             San shao ye de Jian 3D     CN      cmn
# 258555                 El cascanueces y los cuatro reinos     UY      NaN
# 263145                                         Le Mans 3D     PL      NaN
# 265149                               El hijo de Piegrande     UY      NaN
# 266740                Rascacielos: Rescate en las alturas     UY      NaN
# 270095                                         Wifi Ralph     UY      NaN
# 271255                                  Detective Pikachu     UY      NaN
# 280230                                            Aladdín     UY      NaN
# 281714                                        Pie Pequeño     UY      NaN
# 283702                    Cenicienta y el príncipe oculto     UY       es
# 289260                                      Parque mágico     UY      NaN
# 289744                                      The Mirror 3D     HK       en
# 292975                                X-Men: Dark Phoenix     UY      NaN
# 293175                                La famiilia Monster     UY      NaN
# 298303                          Oz Comic Con The 3D Movie     AU      NaN
# 312572                                 Animales en apuros     UY      NaN
# 312596                                 Un panda en apuros     UY      NaN
# 323520  Yuhuwa Chingudeul, officially subtitled Travel...     KR      NaN
# 323521                      Yoohoo and Friends: The Movie     KR      NaN
# 326656                             Apollo 11: First Steps     US      NaN
#
#        types    attributes  is_original_title
# 304      NaN   3-D version                0.0
# 305      NaN   3-D version                0.0
# 306      NaN   3-D version                0.0
# 337      NaN   3-D version                0.0
# 338      NaN   3-D version                0.0
# 545      NaN   3-D version                0.0
# 825      NaN  IMAX version                0.0
# 879      NaN   3-D version                0.0
# 888      NaN  IMAX version                0.0
# 1090     NaN   3-D version                0.0
# 1159     NaN   3-D version                0.0
# 1214     NaN   3-D version                0.0
# 1884     NaN   3-D version                0.0
# 1907     NaN   3-D version                0.0
# 1912     NaN   3-D version                0.0
# 2448     NaN   3-D version                0.0
# 2544     NaN   3-D version                0.0
# 3049     NaN   3-D version                0.0
# 3476     NaN   3-D version                0.0
# 3479     NaN   3-D version                0.0
# 3547     NaN   3-D version                0.0
# 3548     NaN   3-D version                0.0
# 3647     NaN   3-D version                0.0
# 3724     NaN   3-D version                0.0
# 3740     NaN   3-D version                0.0
# 3781     NaN   3-D version                0.0
# 4014     NaN  IMAX version                0.0
# 4237     NaN   3-D version                0.0
# 4249     NaN   3-D version                0.0
# 4604     NaN  IMAX version                0.0
# ...      ...           ...                ...
# 230725   NaN   3-D version                0.0
# 230742   NaN   3-D version                0.0
# 235458   NaN   3-D version                0.0
# 235473   NaN   3-D version                0.0
# 235691   NaN   3-D version                0.0
# 236737   NaN   3-D version                0.0
# 240313   NaN   3-D version                0.0
# 240523   NaN  IMAX version                0.0
# 241072   NaN   3-D version                0.0
# 248837   NaN   3-D version                0.0
# 250669   NaN   3-D version                0.0
# 258555   NaN   3-D version                0.0
# 263145   NaN   3-D version                0.0
# 265149   NaN   3-D version                0.0
# 266740   NaN   3-D version                0.0
# 270095   NaN   3-D version                0.0
# 271255   NaN   3-D version                0.0
# 280230   NaN   3-D version                0.0
# 281714   NaN   3-D version                0.0
# 283702   NaN   3-D version                0.0
# 289260   NaN   3-D version                0.0
# 289744   NaN   3-D version                0.0
# 292975   NaN   3-D version                0.0
# 293175   NaN   3-D version                0.0
# 298303   NaN   3-D version                0.0
# 312572   NaN   3-D version                0.0
# 312596   NaN   3-D version                0.0
# 323520   NaN  IMAX version                0.0
# 323521   NaN   3-D version                0.0
# 326656   NaN  IMAX version                0.0
#
# [327 rows x 13 columns]

# %% [markdown]
# ### Merge common_id with gross on primary title

# %%
akas_df.attributes.value_counts()
# ['3-D version', 'IMAX version']
# Out:
# new title                               1700
# alternative spelling                    1394
# literal English title                   1054
# complete title                          1034
# original subtitled version               879
# informal English title                   816
# transliterated ISO-LATIN-1 title         695
# dubbed version                           645
# short title                              640
# alternative transliteration              611
# DVD box title                            601
# literal title                            490
# original script title                    300
# 3-D version                              292
# promotional title                        285
# informal title                           274
# Berlin film festival title               244
# long title                               232
# poster title                             225
# cable TV title                           204
# informal literal English title           202
# subtitle                                 154
# pre-release title                        145
# reissue title                            138
# informal short title                     134
# informal alternative title               127
# theatrical title                         126
# segment title                            113
# informal literal title                   110
# literal translation of working title     104
#                                         ...
# Venice film festival title                16
# orthographically correct title            15
# first part title                          15
# teaser title                              15
# DVD menu title                            14
# long new title                            13
# censored version                          12
# second part title                         12
# cut version                               12
# première title                            12
# video box title                           11
# second copyright title                    11
# third part title                           9
# anthology series                           8
# uncensored intended title                  7
# bowdlerized title                          7
# video catalogue title                      6
# correct transliteration                    5
# Los Angeles premiere title                 4
# english transliteration                    3
# expansion title                            2
# second season title                        2
# soft porn version                          2
# first episode title                        2
# unauthorized video title                   2
# X-rated version                            1
# TV listings title                          1
# first season title                         1
# 8mm release title                          1
# reissue titleshort version                1
# Name: attributes, Length: 77, dtype: int64

# %%
akas_df.types.value_counts()
# Out:
# imdbDisplay         100461
# original             44700
# working               8680
# alternative           6564
# festival              3307
# dvd                   2995
# tv                    1617
# video                  121
# dvdimdbDisplay          1
# festivalworking         1
# Name: types, dtype: int64

# %%
tech_movies_df = akas_df[akas_df.attributes.isin(['3-D version', 'IMAX version'])]
domestic_tech_movies = tech_movies_df[tech_movies_df.region == 'US']
domestic_tech_movies.shape
# Out:
# (50, 8)

# %%
domestic_tech_movies.head()
# Out:
#        title_id  ordering                                       title region  \
# 12    tt0369610        21                           Jurassic World 3D     US
# 109   tt1014759        23  Alice in Wonderland: An IMAX 3D Experience     US
# 1494  tt1869504         3             Jillian's Travels: Africa in 3D     US
# 2586  tt2215719        10                   Katy Perry: Part of Me 3D     US
# 2907  tt1104001        12          Tron Legacy: An IMAX 3D Experience     US
#
#      language types    attributes  is_original_title
# 12        NaN   NaN   3-D version                0.0
# 109       NaN   NaN  IMAX version                0.0
# 1494      NaN   NaN   3-D version                0.0
# 2586      NaN   NaN   3-D version                0.0
# 2907      NaN   NaN  IMAX version                0.0

# %%
domestic_tech_movies.loc[:, ['title', 'title_id', 'region', 'attributes']]
# Out:
#                                                     title   title_id region  \
# 12                                      Jurassic World 3D  tt0369610     US
# 109            Alice in Wonderland: An IMAX 3D Experience  tt1014759     US
# 1494                      Jillian's Travels: Africa in 3D  tt1869504     US
# 2586                            Katy Perry: Part of Me 3D  tt2215719     US
# 2907                   Tron Legacy: An IMAX 3D Experience  tt1104001     US
# 8290                       Inception: The IMAX Experience  tt1375666     US
# 10828                     Real Steel: The IMAX Experience  tt0433035     US
# 29965     How to Train Your Dragon: An IMAX 3D Experience  tt0892769     US
# 30356                                        Immortals 3D  tt1253864     US
# 31895                                    Get Squirrely 3D  tt2097333     US
# 40625                  Toy Story 3: An IMAX 3D Experience  tt0435761     US
# 46742                      Fast Five: The IMAX Experience  tt1596343     US
# 59631          The Dark Knight Rises: The IMAX Experience  tt1345836     US
# 68008                   Transformers: Dark of the Moon 3D  tt1399103     US
# 68011   Transformers: Dark of the Moon - An IMAX 3D Ex...  tt1399103     US
# 70689                        Super 8: The IMAX Experience  tt1650062     US
# 77934                                         Ice Bear 3D  tt2403931     US
# 86572                                 The Darkest Hour 3D  tt1093357     US
# 92224   Mission: Impossible - Ghost Protocol: The IMAX...  tt1229238     US
# 99264                                           Karnoctus  tt2357423     US
# 106910                                          Anomalisa  tt2401878     US
# 109506              Assassin's Creed: The IMAX Experience  tt2094766     US
# 113911                     Contagion: The IMAX Experience  tt1598778     US
# 124574    Resident Evil: Afterlife: An IMAX 3D Experience  tt1220634     US
# 125546                                     The Great Wall  tt2034800     US
# 129886                                     The Martian 3D  tt3659388     US
# 130201   The Twilight Saga: Eclipse - The IMAX Experience  tt1325004     US
# 135640    Harry Potter and the Deathly Hallows: Part 2 3D  tt1201607     US
# 135659                    Iron Man 2: The IMAX Experience  tt1228705     US
# 135914                                      Iron Doors 3D  tt1520956     US
# 141964                                   Sausage Party 3D  tt1700841     US
# 142444                            Hotel Transylvania 2 3D  tt2510894     US
# 143593         Shrek Forever After: An IMAX 3D Experience  tt0892791     US
# 143607                        Shrek 3D: The Final Chapter  tt0892791     US
# 146308                                 My Soul to Take 3D  tt0872230     US
# 149072                                   Jigsaw Puzzle 3D  tt1477076     US
# 152054              I Am Number Four: The IMAX Experience  tt1464540     US
# 152146        Dr. Seuss' The Lorax: An IMAX 3D Experience  tt1482459     US
# 154275                              The House of Magic 3D  tt3148834     US
# 154345                  Sucker Punch: The IMAX Experience  tt0978764     US
# 161483                      Captain America: Civil War 3D  tt3498820     US
# 168042                                 Beyond the Edge 3D  tt2468638     US
# 170714                                        Meerkats 3D  tt2713406     US
# 200647                                  Camp Blood III 3D  tt3096810     US
# 260713                       Dunkirk: The IMAX Experience  tt5013056     US
# 283284                                           Slash 3D  tt4027402     US
# 291453                              The Lego Batman Movie  tt4116284     US
# 313477                                 Kong: Skull Island  tt3731562     US
# 315449                             Apollo 11: First Steps  tt8760684     US
# 329408                  The Predator: The IMAX Experience  tt3829266     US
#
#           attributes
# 12       3-D version
# 109     IMAX version
# 1494     3-D version
# 2586     3-D version
# 2907    IMAX version
# 8290    IMAX version
# 10828   IMAX version
# 29965   IMAX version
# 30356    3-D version
# 31895    3-D version
# 40625   IMAX version
# 46742   IMAX version
# 59631   IMAX version
# 68008    3-D version
# 68011   IMAX version
# 70689   IMAX version
# 77934    3-D version
# 86572    3-D version
# 92224   IMAX version
# 99264   IMAX version
# 106910   3-D version
# 109506  IMAX version
# 113911  IMAX version
# 124574  IMAX version
# 125546  IMAX version
# 129886   3-D version
# 130201  IMAX version
# 135640   3-D version
# 135659  IMAX version
# 135914   3-D version
# 141964   3-D version
# 142444   3-D version
# 143593  IMAX version
# 143607   3-D version
# 146308   3-D version
# 149072   3-D version
# 152054  IMAX version
# 152146  IMAX version
# 154275   3-D version
# 154345  IMAX version
# 161483   3-D version
# 168042   3-D version
# 170714   3-D version
# 200647   3-D version
# 260713  IMAX version
# 283284   3-D version
# 291453  IMAX version
# 313477  IMAX version
# 315449  IMAX version
# 329408  IMAX version

# %%
# for bom.basics
# basics_df.known_for_titles[0].split(',')
